# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt # plotting
import matplotlib.image as mpimg

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os # accessing directory structure

# %%
DATASET_PATH = "/media/vidhikatkoria/Research/fashion-product-images-small/myntradataset/"
print(os.listdir(DATASET_PATH))
# Out:
# ['styles.csv', 'images']

# %%
df = pd.read_csv(DATASET_PATH + "styles.csv")
df['image'] = df.apply(lambda row: str(row['id']) + ".jpg", axis=1)
# df = df.sample(frac=1).reset_index(drop=True)
df[6040:6050]
# Out:
#          id  gender masterCategory subCategory            articleType  \
# 6040  52100   Women        Apparel     Topwear                 Kurtas
# 6041  14715     Men        Apparel     Topwear                 Shirts
# 6042  44065     Men  Personal Care   Fragrance  Perfume and Body Mist
# 6043   5342     Men       Footwear       Shoes           Casual Shoes
# 6044  37597    Boys        Apparel     Topwear                Tshirts
# 6045  11267     Men        Apparel  Bottomwear               Trousers
# 6046  41517     Men    Accessories     Eyewear             Sunglasses
# 6047  33137   Women       Footwear       Shoes                  Heels
# 6048  24180  Unisex       Footwear       Shoes           Casual Shoes
# 6049  44859     Men        Apparel     Topwear                Tshirts
#
#      baseColour  season    year   usage  \
# 6040        Red  Summer  2012.0  Ethnic
# 6041      White    Fall  2011.0  Formal
# 6042       Blue  Spring  2017.0  Casual
# ...

# %%
#get category wise image list
category_list = []
x = df.copy()
x = x.loc[df['articleType'] == 'Shirts','image']

# %%
xy = df.copy()
xy = xy.loc[df['articleType'].isin(['Shirts', 'Tshirts','Sarees','Kurtas']),'image']
xy.count()
# Out:
# 12558

# %%
# extract only 1000 images for each category except saree
import shutil, os
dest_path = "/media/vidhikatkoria/Research/vr_dataset/dress_dataset/"
category_list = list(xy)
for f in category_list[:1000]:
    try :
        image_path = os.path.join(DATASET_PATH,'images/',f)
        shutil.copy(image_path, dest_path)
    except:
        pass

# %%
listOfFiles = os.listdir(dest_path)
# print(listOfFiles)

# %%
len(listOfFiles)
# Out:
# 35

# %%
p = df.copy()
criterion = lambda row: row['image'] in listOfFiles
not_in = p[p.apply(criterion, axis=1)]
not_in
# Out:
#           id gender masterCategory subCategory articleType baseColour  season  \
# 0      15970    Men        Apparel     Topwear      Shirts  Navy Blue    Fall
# 4      53759    Men        Apparel     Topwear     Tshirts       Grey  Summer
# 5       1855    Men        Apparel     Topwear     Tshirts       Grey  Summer
# 6      30805    Men        Apparel     Topwear      Shirts      Green  Summer
# 7      26960  Women        Apparel     Topwear      Shirts     Purple  Summer
# ...      ...    ...            ...         ...         ...        ...     ...
# 44434   1644    Men        Apparel     Topwear     Tshirts        Red    Fall
# 44436  30614    Men        Apparel     Topwear     Tshirts      Black  Summer
# 44437  13496    Men        Apparel     Topwear     Tshirts       Blue    Fall
# 44439  12544  Women        Apparel     Topwear     Tshirts      Peach    Fall
# 44443  18842    Men        Apparel     Topwear     Tshirts       Blue    Fall
#
# ...

# %%
criterion = lambda row: row['image'] in listOfFiles
not_in = df[df.apply(criterion, axis=1)]
not_in
# Out:
#           id gender masterCategory subCategory articleType baseColour  season  \
# 0      15970    Men        Apparel     Topwear      Shirts  Navy Blue    Fall
# 4      53759    Men        Apparel     Topwear     Tshirts       Grey  Summer
# 5       1855    Men        Apparel     Topwear     Tshirts       Grey  Summer
# 6      30805    Men        Apparel     Topwear      Shirts      Green  Summer
# 7      26960  Women        Apparel     Topwear      Shirts     Purple  Summer
# ...      ...    ...            ...         ...         ...        ...     ...
# 44434   1644    Men        Apparel     Topwear     Tshirts        Red    Fall
# 44436  30614    Men        Apparel     Topwear     Tshirts      Black  Summer
# 44437  13496    Men        Apparel     Topwear     Tshirts       Blue    Fall
# 44439  12544  Women        Apparel     Topwear     Tshirts      Peach    Fall
# 44443  18842    Men        Apparel     Topwear     Tshirts       Blue    Fall
#
# ...

# %%
not_in.drop(["id","gender", "masterCategory","subCategory","baseColour","season","year","usage","productDisplayName"], axis = 1, inplace = True)
not_in
# Out:
#       articleType      image
# 0          Shirts  15970.jpg
# 4         Tshirts  53759.jpg
# 5         Tshirts   1855.jpg
# 6          Shirts  30805.jpg
# 7          Shirts  26960.jpg
# ...           ...        ...
# 44434     Tshirts   1644.jpg
# 44436     Tshirts  30614.jpg
# 44437     Tshirts  13496.jpg
# 44439     Tshirts  12544.jpg
# 44443     Tshirts  18842.jpg
#
# [12555 rows x 2 columns]

# %%
d = not_in.rename(columns={"articleType": "label"})
d
# Out:
#          label      image
# 0       Shirts  15970.jpg
# 4      Tshirts  53759.jpg
# 5      Tshirts   1855.jpg
# 6       Shirts  30805.jpg
# 7       Shirts  26960.jpg
# ...        ...        ...
# 44434  Tshirts   1644.jpg
# 44436  Tshirts  30614.jpg
# 44437  Tshirts  13496.jpg
# 44439  Tshirts  12544.jpg
# 44443  Tshirts  18842.jpg
#
# [12555 rows x 2 columns]

# %%
dataf = d.reset_index(drop=True, inplace=True)

# %%
d

# %%
d.to_csv('/media/vidhikatkoria/Research/vr_dataset/data_sp.csv', index=False)
